# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://i.imgur.com/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),    
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),


    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    # YOUR CODE HERE: Add loss and metric
    loss="binary_crossentropy",
    metrics=["binary_accuracy"]
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 45s 423ms/step - loss: 0.6828 - binary_accuracy: 0.5751 - val_loss: 0.6765 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.6701 - binary_accuracy: 0.5873 - val_loss: 0.6614 - val_binary_accuracy: 0.5953
# Epoch 3/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6619 - binary_accuracy: 0.5949 - val_loss: 0.6528 - val_binary_accuracy: 0.6139
# Epoch 4/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6532 - binary_accuracy: 0.6066 - val_loss: 0.6444 - val_binary_accuracy: 0.6211
# Epoch 5/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6465 - binary_accuracy: 0.6144 - val_loss: 0.6366 - val_binary_accuracy: 0.6244
# Epoch 6/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6408 - binary_accuracy: 0.6234 - val_loss: 0.6294 - val_binary_accuracy: 0.6343
# Epoch 7/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6317 - binary_accuracy: 0.6334 - val_loss: 0.6222 - val_binary_accuracy: 0.6401
# Epoch 8/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6242 - binary_accuracy: 0.6336 - val_loss: 0.6158 - val_binary_accuracy: 0.6533
# Epoch 9/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6140 - binary_accuracy: 0.6572 - val_loss: 0.6126 - val_binary_accuracy: 0.6593
# Epoch 10/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6038 - binary_accuracy: 0.6549 - val_loss: 0.5982 - val_binary_accuracy: 0.6694
# Epoch 11/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5966 - binary_accuracy: 0.6748 - val_loss: 0.6099 - val_binary_accuracy: 0.6565
# Epoch 12/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5800 - binary_accuracy: 0.7039 - val_loss: 0.5750 - val_binary_accuracy: 0.6951
# Epoch 13/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5636 - binary_accuracy: 0.7108 - val_loss: 0.5592 - val_binary_accuracy: 0.7179
# Epoch 14/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5377 - binary_accuracy: 0.7325 - val_loss: 0.5358 - val_binary_accuracy: 0.7302
# Epoch 15/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5148 - binary_accuracy: 0.7547 - val_loss: 0.5037 - val_binary_accuracy: 0.7541
# Epoch 16/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.4943 - binary_accuracy: 0.7663 - val_loss: 0.5401 - val_binary_accuracy: 0.7226
# Epoch 17/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.4651 - binary_accuracy: 0.7870 - val_loss: 0.4615 - val_binary_accuracy: 0.7834
# Epoch 18/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.4230 - binary_accuracy: 0.8110 - val_loss: 0.4617 - val_binary_accuracy: 0.7903
# Epoch 19/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3982 - binary_accuracy: 0.8237 - val_loss: 0.4318 - val_binary_accuracy: 0.8036
# Epoch 20/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3681 - binary_accuracy: 0.8364 - val_loss: 0.4271 - val_binary_accuracy: 0.8086
# Epoch 21/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3498 - binary_accuracy: 0.8474 - val_loss: 0.4227 - val_binary_accuracy: 0.8163
# Epoch 22/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3196 - binary_accuracy: 0.8550 - val_loss: 0.4350 - val_binary_accuracy: 0.8125
# Epoch 23/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3180 - binary_accuracy: 0.8575 - val_loss: 0.4129 - val_binary_accuracy: 0.8202
# Epoch 24/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2723 - binary_accuracy: 0.8782 - val_loss: 0.4159 - val_binary_accuracy: 0.8244
# Epoch 25/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2548 - binary_accuracy: 0.8888 - val_loss: 0.4808 - val_binary_accuracy: 0.8062
# Epoch 26/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2632 - binary_accuracy: 0.8843 - val_loss: 0.6424 - val_binary_accuracy: 0.7636
# Epoch 27/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2765 - binary_accuracy: 0.8732 - val_loss: 0.5850 - val_binary_accuracy: 0.7597
# Epoch 28/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2589 - binary_accuracy: 0.8734 - val_loss: 0.4580 - val_binary_accuracy: 0.8274
# Epoch 29/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2120 - binary_accuracy: 0.9074 - val_loss: 0.4571 - val_binary_accuracy: 0.8327
# Epoch 30/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1933 - binary_accuracy: 0.9154 - val_loss: 0.4278 - val_binary_accuracy: 0.8313
# Epoch 31/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2077 - binary_accuracy: 0.9111 - val_loss: 0.4484 - val_binary_accuracy: 0.8244
# Epoch 32/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2012 - binary_accuracy: 0.9152 - val_loss: 0.4461 - val_binary_accuracy: 0.8305
# Epoch 33/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1767 - binary_accuracy: 0.9220 - val_loss: 0.4305 - val_binary_accuracy: 0.8436
# Epoch 34/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1359 - binary_accuracy: 0.9465 - val_loss: 0.5170 - val_binary_accuracy: 0.8321
# Epoch 35/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1396 - binary_accuracy: 0.9394 - val_loss: 0.5904 - val_binary_accuracy: 0.8303
# Epoch 36/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1303 - binary_accuracy: 0.9445 - val_loss: 0.5575 - val_binary_accuracy: 0.8396
# Epoch 37/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1061 - binary_accuracy: 0.9556 - val_loss: 0.4489 - val_binary_accuracy: 0.8448
# Epoch 38/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1157 - binary_accuracy: 0.9535 - val_loss: 0.5515 - val_binary_accuracy: 0.8347
# Epoch 39/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1141 - binary_accuracy: 0.9525 - val_loss: 0.4981 - val_binary_accuracy: 0.8386
# Epoch 40/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1016 - binary_accuracy: 0.9584 - val_loss: 0.4473 - val_binary_accuracy: 0.8478
# Epoch 41/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1076 - binary_accuracy: 0.9549 - val_loss: 0.4822 - val_binary_accuracy: 0.8365
# Epoch 42/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0917 - binary_accuracy: 0.9595 - val_loss: 0.5501 - val_binary_accuracy: 0.8190
# Epoch 43/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0805 - binary_accuracy: 0.9668 - val_loss: 0.6301 - val_binary_accuracy: 0.8331
# Epoch 44/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0773 - binary_accuracy: 0.9707 - val_loss: 0.5332 - val_binary_accuracy: 0.8533
# Epoch 45/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0565 - binary_accuracy: 0.9773 - val_loss: 0.6176 - val_binary_accuracy: 0.8493
# Epoch 46/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0463 - binary_accuracy: 0.9808 - val_loss: 0.7576 - val_binary_accuracy: 0.8404
# Epoch 47/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0435 - binary_accuracy: 0.9834 - val_loss: 0.6295 - val_binary_accuracy: 0.8529
# Epoch 48/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0400 - binary_accuracy: 0.9844 - val_loss: 0.7158 - val_binary_accuracy: 0.8531
# Epoch 49/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0352 - binary_accuracy: 0.9863 - val_loss: 0.6991 - val_binary_accuracy: 0.8531
# Epoch 50/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0347 - binary_accuracy: 0.9873 - val_loss: 0.7731 - val_binary_accuracy: 0.8578

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
